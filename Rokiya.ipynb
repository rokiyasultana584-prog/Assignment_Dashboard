# %% [markdown]
# <a href="https://colab.research.google.com/github/rokiyasultana584-prog/Assignment_Dashboard/blob/main/Rokiya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
# H1: Write a program to perform the subtraction, multipllication and division

# %%
value1=768
value2=899
sub= value1-value2
multi=value1*value2
div1=value1/value2
div2=value1//value2
print(sub)
print(multi)
print(div1)
print(div2)
print(value1%value2)
print("substratcion: {:.1f}" .format(sub))
print("multiplication: {:.2f}".format(multi))
print("division: {:.3f}".format(div1))
# Out:
# -131
# 690432
# 0.8542825361512792
# 0
# 768
# substratcion: -131.0
# multiplication: 690432.00
# division: 0.854

# %%
value1 = 768
value2 = 899

sub = value1 - value2
multi = value1 * value2
div1 = value1 / value2
mod = value1 % value2

print(sub)
print(multi)
print(div1)
print(mod)

print("Subtraction:", sub)
print("Multiplication:", multi)
print("Division:", round(div1,3))
print("Modulus:", mod)
# Out:
# -131
# 690432
# 0.8542825361512792
# 768
# Subtraction: -131
# Multiplication: 690432
# Division: 0.854
# Modulus: 768

# %% [markdown]
# H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.

# %%
id= "SM-ML-2026-B2-049"
name="Rokiya Sultana"
Batch= 2
Hometown="Cumilla"

print("id:",id, "\n", "Name:", name, "\t", "Batch no:", Batch, "\t", "Hometown:", Hometown)
# Out:
# id: SM-ML-2026-B2-049
#  Name: Rokiya Sultana 	 Batch no: 2 	 Hometown: Cumilla

# %% [markdown]
# H3: Write a program to change values of an integer variable

# %%
value=698
print("old value:", value)
value=356
print("new value: ", value)
# Out:
# old value: 698
# new value:  356

# %% [markdown]
# H4: Write a program to take two string numbers and convert them to integers using explicit type conversion

# %%
ID= "049"
Batch="02"
print(ID, type(ID))
print(Batch, type(Batch))
concatenating= ID+Batch
print("Concatenate: ", concatenating)
ID=int(ID)
Batch=int(Batch)
print(ID, type(ID))
print(Batch, type(Batch))
concatenating= ID+Batch
print("Concatenate: ", concatenating)
# Out:
# 049 <class 'str'>
# 02 <class 'str'>
# Concatenate:  04902
# 49 <class 'int'>
# 2 <class 'int'>
# Concatenate:  51

# %% [markdown]
# H5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.

# %%
num1=578
num2=789
num3=798
avg=(num1+num2+num3)/3
print(avg)

print(round(avg))
# Out:
# 721.6666666666666
# 722

# %% [markdown]
# H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input

# %%
print("welcome to the python calculator")
print("type a for Addition, s for Substraction, m for multiplication, d for division")
typ= input("type that letter: ")
if typ=="a":
  num1=float(input("input your first number:"))
  num2=float(input("input your first number:"))
  add=num1+num2
  print("Addition of the numbers are:", add)
elif typ=="s":
  num1=float(input("input your first number:"))
  num2=float(input("input your first number:"))
  sub=num1-num2
  print("Substraction of the numbers are:", sub)

elif typ=="m":
  num1=float(input("input your first number:"))
  num2=float(input("input your first number:"))
  multi=num1*num2
  print("Multiplication of the numbers are:", multi)
elif typ=="d":
  num1=float(input("input your first number:"))
  num2=float(input("input your first number:"))
  div=num1/num2
  print("Division of the numbers are:", div)
else:
  print("Sorry! You mistake, retype a/s/m/d")
print("done!")
# Out:
# welcome to the python calculator
# type a for Addition, s for Substraction, m for multiplication, d for division
# type that letter: d
# input your first number:7900
# input your first number:45
# Division of the numbers are: 175.55555555555554
# done!

# %% [markdown]
# H7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant.

# %%
char=input("enter letter: ")
#if char.lower()== "a" or "e" or "i" or "o" or "u": #Return error
if char.lower() in "aeiou":
  print("vowel")
else:
  print("consonant")
# Out:
# enter letter: t
# consonant

# %% [markdown]
# H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.

# %%
print("Temperature converstion calculator")
print("type c for celsius to farenheit")
print("type f for farenheit to celsius")
print("type q for quit")
while True:
  temp=str(input("c f or q?: "))
  if temp.lower()== "q":
    print("quit the program")
    break
  elif temp.lower()=="f":
    try:
      F=float(input("how much is the temperation in Farenheit: "))
      C=(5/9)*(F-32)
      print(f"Conversion: The tempareture is {C:.2f} degree Celsius")
    except:
      print("invalid input! please type again")
  elif temp.lower()=="c":
    try:
      C=float(input("how much is the temperation in Celsium: "))
      F=(9/5)*C+32
      print(f" COnversion: The temperatur is {F:.2f} degree farenheit")
    except:
      print("invalid input! please type again")
  else:
    print("invalid input! please type 'c', 'f', or 'q'")

print("thank you")
# Out:
# Temperature converstion calculator
# type c for celsius to farenheit
# type f for farenheit to celsius
# type q for quit
# c f or q?: c
# how much is the temperation in Celsium: 34
#  COnversion: The temperatur is 93.20 degree farenheit
# c f or q?: f
# how much is the temperation in Farenheit: 217
# Conversion: The tempareture is 102.78 degree Celsius
# c f or q?: q
# quit the program
# thank you

# %% [markdown]
# H9: Write a program that asks the user to enter three numbers and determines which one is the largest.

# %%
while True:
  print("type a for entering numbers, q for quit")
  user_input=str(input())
  if user_input.lower()=="q":
    print("quit the program")
    break
  elif user_input.lower()=="a":
    print("enter the numbers")
    num1=float(input("enter first number: "))
    num2=float(input("enter second number: "))
    num3=float(input("enter third number: "))
    if num1>num2 and num2>num3:
        print(f"the largest number is num1: {num1}")
    elif num2>num1 and num2>num3:
        print(f"the largest number is num2: {num2}")
    else:
        print(f"the largest number is num3: {num3}")
    break
  else:
    print("invalid input! please type again")


print("well done!")
# Out:
# type a for entering numbers, q for quit
# a
# enter the numbers
# enter first number: 34567
# enter second number: 998765
# enter third number: 24567
# the largest number is num2: 998765.0
# well done!

# %% [markdown]
# H10: Write a program that prompts the user to input a number N and prints all even numbers between 1 and N using a for loop.

# %%
N=int(input())
for x in range(0, N+1, 2):
  print(x)
# Out:
# 0
# 0

# %% [markdown]
#  H11: Write a program that prompts the user to input a number N and calculates the sum of all numbers from 1 to N that are divisible by 3 or 5.

# %%
sum=0
N=int(input("N: "))
for x in range(1, N+1):
  if x%3==0 or x%5==0:
    print(x)
    sum=sum+x
    print(f" sum is {sum}")
print(f"final sum of all that numbers is {sum}")
# Out:
# N: 2
# final sum of all that numbers is 0

# %% [markdown]
# H12. Write a program that prompts the user to input a number n and prints the multiplication table of n (1 to 10) using a for loop.

# %%
N=int(input("N: "))
for x in range(2, N+1):
  print(f"well done! Multiplication of {x}")
  for y in range(1, 11):
    multi=x*y
    print(f" {x}*{y}={multi}")
# Out:
# N: 45
# well done! Multiplication of 2
#  2*1=2
#  2*2=4
#  2*3=6
#  2*4=8
#  2*5=10
#  2*6=12
#  2*7=14
#  2*8=16
#  2*9=18
#  2*10=20
# well done! Multiplication of 3
#  3*1=3
#  3*2=6
#  3*3=9
#  3*4=12
#  3*5=15
#  3*6=18
#  3*7=21
#  3*8=24
#  3*9=27
#  3*10=30
# well done! Multiplication of 4
#  4*1=4
#  4*2=8
#  4*3=12
#  4*4=16
#  4*5=20
#  4*6=24
#  4*7=28
#  4*8=32
#  4*9=36
#  4*10=40
# well done! Multiplication of 5
#  5*1=5
#  5*2=10
#  5*3=15
#  5*4=20
#  5*5=25
#  5*6=30
#  5*7=35
#  5*8=40
#  5*9=45
#  5*10=50
# well done! Multiplication of 6
#  6*1=6
#  6*2=12
#  6*3=18
#  6*4=24
#  6*5=30
#  6*6=36
#  6*7=42
#  6*8=48
#  6*9=54
#  6*10=60
# well done! Multiplication of 7
#  7*1=7
#  7*2=14
#  7*3=21
#  7*4=28
#  7*5=35
#  7*6=42
#  7*7=49
#  7*8=56
#  7*9=63
#  7*10=70
# well done! Multiplication of 8
#  8*1=8
#  8*2=16
#  8*3=24
#  8*4=32
#  8*5=40
#  8*6=48
#  8*7=56
#  8*8=64
#  8*9=72
#  8*10=80
# well done! Multiplication of 9
#  9*1=9
#  9*2=18
#  9*3=27
#  9*4=36
#  9*5=45
#  9*6=54
#  9*7=63
#  9*8=72
#  9*9=81
#  9*10=90
# well done! Multiplication of 10
#  10*1=10
#  10*2=20
#  10*3=30
#  10*4=40
#  10*5=50
#  10*6=60
#  10*7=70
#  10*8=80
#  10*9=90
#  10*10=100
# well done! Multiplication of 11
#  11*1=11
#  11*2=22
#  11*3=33
#  11*4=44
#  11*5=55
#  11*6=66
#  11*7=77
#  11*8=88
#  11*9=99
#  11*10=110
# well done! Multiplication of 12
#  12*1=12
#  12*2=24
#  12*3=36
#  12*4=48
#  12*5=60
#  12*6=72
#  12*7=84
#  12*8=96
#  12*9=108
#  12*10=120
# well done! Multiplication of 13
#  13*1=13
#  13*2=26
#  13*3=39
#  13*4=52
#  13*5=65
#  13*6=78
#  13*7=91
#  13*8=104
#  13*9=117
#  13*10=130
# well done! Multiplication of 14
#  14*1=14
#  14*2=28
#  14*3=42
#  14*4=56
#  14*5=70
#  14*6=84
#  14*7=98
#  14*8=112
#  14*9=126
#  14*10=140
# well done! Multiplication of 15
#  15*1=15
#  15*2=30
#  15*3=45
#  15*4=60
#  15*5=75
#  15*6=90
#  15*7=105
#  15*8=120
#  15*9=135
#  15*10=150
# well done! Multiplication of 16
#  16*1=16
#  16*2=32
#  16*3=48
#  16*4=64
#  16*5=80
#  16*6=96
#  16*7=112
#  16*8=128
#  16*9=144
#  16*10=160
# well done! Multiplication of 17
#  17*1=17
#  17*2=34
#  17*3=51
#  17*4=68
#  17*5=85
#  17*6=102
#  17*7=119
#  17*8=136
#  17*9=153
#  17*10=170
# well done! Multiplication of 18
#  18*1=18
#  18*2=36
#  18*3=54
#  18*4=72
#  18*5=90
#  18*6=108
#  18*7=126
#  18*8=144
#  18*9=162
#  18*10=180
# well done! Multiplication of 19
#  19*1=19
#  19*2=38
#  19*3=57
#  19*4=76
#  19*5=95
#  19*6=114
#  19*7=133
#  19*8=152
#  19*9=171
#  19*10=190
# well done! Multiplication of 20
#  20*1=20
#  20*2=40
#  20*3=60
#  20*4=80
#  20*5=100
#  20*6=120
#  20*7=140
#  20*8=160
#  20*9=180
#  20*10=200
# well done! Multiplication of 21
#  21*1=21
#  21*2=42
#  21*3=63
#  21*4=84
#  21*5=105
#  21*6=126
#  21*7=147
#  21*8=168
#  21*9=189
#  21*10=210
# well done! Multiplication of 22
#  22*1=22
#  22*2=44
#  22*3=66
#  22*4=88
#  22*5=110
#  22*6=132
#  22*7=154
#  22*8=176
#  22*9=198
#  22*10=220
# well done! Multiplication of 23
#  23*1=23
#  23*2=46
#  23*3=69
#  23*4=92
#  23*5=115
#  23*6=138
#  23*7=161
#  23*8=184
#  23*9=207
#  23*10=230
# well done! Multiplication of 24
#  24*1=24
#  24*2=48
#  24*3=72
#  24*4=96
#  24*5=120
#  24*6=144
#  24*7=168
#  24*8=192
#  24*9=216
#  24*10=240
# well done! Multiplication of 25
#  25*1=25
#  25*2=50
#  25*3=75
#  25*4=100
#  25*5=125
#  25*6=150
#  25*7=175
#  25*8=200
#  25*9=225
#  25*10=250
# well done! Multiplication of 26
#  26*1=26
#  26*2=52
#  26*3=78
#  26*4=104
#  26*5=130
#  26*6=156
#  26*7=182
#  26*8=208
#  26*9=234
#  26*10=260
# well done! Multiplication of 27
#  27*1=27
#  27*2=54
#  27*3=81
#  27*4=108
#  27*5=135
#  27*6=162
#  27*7=189
#  27*8=216
#  27*9=243
#  27*10=270
# well done! Multiplication of 28
#  28*1=28
#  28*2=56
#  28*3=84
#  28*4=112
#  28*5=140
#  28*6=168
#  28*7=196
#  28*8=224
#  28*9=252
#  28*10=280
# well done! Multiplication of 29
#  29*1=29
#  29*2=58
#  29*3=87
#  29*4=116
#  29*5=145
#  29*6=174
#  29*7=203
#  29*8=232
#  29*9=261
#  29*10=290
# well done! Multiplication of 30
#  30*1=30
#  30*2=60
#  30*3=90
#  30*4=120
#  30*5=150
#  30*6=180
#  30*7=210
#  30*8=240
#  30*9=270
#  30*10=300
# well done! Multiplication of 31
#  31*1=31
#  31*2=62
#  31*3=93
#  31*4=124
#  31*5=155
#  31*6=186
#  31*7=217
#  31*8=248
#  31*9=279
#  31*10=310
# well done! Multiplication of 32
#  32*1=32
#  32*2=64
#  32*3=96
#  32*4=128
#  32*5=160
#  32*6=192
#  32*7=224
#  32*8=256
#  32*9=288
#  32*10=320
# well done! Multiplication of 33
#  33*1=33
#  33*2=66
#  33*3=99
#  33*4=132
#  33*5=165
#  33*6=198
#  33*7=231
#  33*8=264
#  33*9=297
#  33*10=330
# well done! Multiplication of 34
#  34*1=34
#  34*2=68
#  34*3=102
#  34*4=136
#  34*5=170
#  34*6=204
#  34*7=238
#  34*8=272
#  34*9=306
#  34*10=340
# well done! Multiplication of 35
#  35*1=35
#  35*2=70
#  35*3=105
#  35*4=140
#  35*5=175
#  35*6=210
#  35*7=245
#  35*8=280
#  35*9=315
#  35*10=350
# well done! Multiplication of 36
#  36*1=36
#  36*2=72
#  36*3=108
#  36*4=144
#  36*5=180
#  36*6=216
#  36*7=252
#  36*8=288
#  36*9=324
#  36*10=360
# well done! Multiplication of 37
#  37*1=37
#  37*2=74
#  37*3=111
#  37*4=148
#  37*5=185
#  37*6=222
#  37*7=259
#  37*8=296
#  37*9=333
#  37*10=370
# well done! Multiplication of 38
#  38*1=38
#  38*2=76
#  38*3=114
#  38*4=152
#  38*5=190
#  38*6=228
#  38*7=266
#  38*8=304
#  38*9=342
#  38*10=380
# well done! Multiplication of 39
#  39*1=39
#  39*2=78
#  39*3=117
#  39*4=156
#  39*5=195
#  39*6=234
#  39*7=273
#  39*8=312
#  39*9=351
#  39*10=390
# well done! Multiplication of 40
#  40*1=40
#  40*2=80
#  40*3=120
#  40*4=160
#  40*5=200
#  40*6=240
#  40*7=280
#  40*8=320
#  40*9=360
#  40*10=400
# well done! Multiplication of 41
#  41*1=41
#  41*2=82
#  41*3=123
#  41*4=164
#  41*5=205
#  41*6=246
#  41*7=287
#  41*8=328
#  41*9=369
#  41*10=410
# well done! Multiplication of 42
#  42*1=42
#  42*2=84
#  42*3=126
#  42*4=168
#  42*5=210
#  42*6=252
#  42*7=294
#  42*8=336
#  42*9=378
#  42*10=420
# well done! Multiplication of 43
#  43*1=43
#  43*2=86
#  43*3=129
#  43*4=172
#  43*5=215
#  43*6=258
#  43*7=301
#  43*8=344
#  43*9=387
#  43*10=430
# well done! Multiplication of 44
#  44*1=44
#  44*2=88
#  44*3=132
#  44*4=176
#  44*5=220
#  44*6=264
#  44*7=308
#  44*8=352
#  44*9=396
#  44*10=440
# well done! Multiplication of 45
#  45*1=45
#  45*2=90
#  45*3=135
#  45*4=180
#  45*5=225
#  45*6=270
#  45*7=315
#  45*8=360
#  45*9=405
#  45*10=450
